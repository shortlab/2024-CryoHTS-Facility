# %%
# %pylab notebook
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
energy = np.array([200000.0, 400000.0, 600000.0, 800000.0, 1000000.0, 1200000.0, 1600000.0, 2000000.0, 2400000.0, 3000000.0])/1e6
rangeH = np.array([20075.0, 32120.0, 48180.0, 68255.0, 88330.0, 112420.0, 160600.0, 220825.0, 285065.0, 397485.0])/1e4
rangeHe = np.array([16060.0, 16060.0, 20075.0, 24090.0, 28105.0, 32120.0, 40150.0, 48180.0, 56210.0, 68255.0])/1e4

fig, ax = plt.subplots()
ax.semilogy(energy, rangeH, color='k', marker='s')
ax.semilogy(energy, rangeHe, color='k', marker='o')
ax.invert_yaxis()
ax.set_xlim(0, 10)
ax.set_ylim(40, 1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (40, 1)
